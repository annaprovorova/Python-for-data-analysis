# %% [markdown]
# # Повторение и закрепление пройденного материала, подготовка к НЭ.
#
# Ссылка на материал на Google Colab https://colab.research.google.com/drive/14p1dTiTEu5BieqgbyCfJzLHhtnJaUb8R?usp=sharing

# %% [markdown]
# ЧАСТЬ А: 8 задач; задачи 1-4 весят по 0.25 балла каждая; задачи 5-8 весят по 0.5 балла каждая. Всего 3 балла из 10.
# Рекомендуемое время выполения 20 минут.
# Примерное время на одну задачу **2,5 минуты** 😲
#
# ЧАСТЬ В: 5 задач; задачи 1-2 весят по 0.6 балла каждая, задача 3 весит 0.8 балла, задачи 4-5 весят по 1 баллу каждая.
# Рекомендуемое время выполения 40 минут.
# Примерное время на одну задачу **8 минут**
#
# ЧАСТЬ С: 2 задачи, каждая оценивается в 1.5 балла.
# Рекомендуемое время выполения 60 минут.
# Примерное время на одну задачу **30 минут**
#
# Всего: 120 минут, 15 задач.
#
# Можно пользоваться вот этим материалом во время решения НЭ: https://edu.hse.ru/pluginfile.php/2690937/mod_label/intro/INTERM_CheatSheetPython.html?time=1695827355360
#
#
# Для подготовки обязательно порешать демоверсию:
# https://edu.hse.ru/course/view.php?id=175587
#
# И просмотреть вот этот источник (учебник "Python как исностранный"):
# https://edu.hse.ru/mod/url/view.php?id=858357

# %% [markdown]
# Мы уже "познакомились" с задачами А-05, А-06, А-07, А-08, B-04, В-05 и даже С-02 (смотри материалы блокнотов 2-4).
#
# Задачи А-01 - А-04 пока оставим на самостоятельный разбор, они очень простые.
#
# Остались совсем не знакомыми нам 4 задачи: B-01, B-02, B-03, C-01. Сегодня разберём их.

# %% [markdown]
# ### Практика по части B:
#
# **B-01:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Условные конструкции. Цикл для перебора последовательностей. Работа со строками.  Подсчет статистик (сумма, среднее, максимум, минимум).*
#
# Реализуйте следующую программу:
#
# Миша хочет проверить, встречаются ли года определенного столетия в тексте. Напишите программу, которая поможет Мише.
#
# **ФОРМАТ ВВОДА**
# - На первой строке через пробел записываются года (гарантировано состоящие из четырех цифр). Гарантируется, что строка состоит минимум из одного года.
#
# - На второй строке вводится целое число — столетие, года которого нужно найти.
#
# **ФОРМАТ ВЫВОДА**
#
# - Целое число — количество годов, относящихся к веку, который интересует Мишу.
#
# - Напомним, что, например, 1999 и 2000 года относятся к 20 веку, а 2001 — уже к 21 веку.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>1346 1569 1324 1312 1852 1389 1567
# 14</pre>
#             </td>
#             <td VALIGN=top><pre>4
# </pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>1499 1500 1501
# 15</pre>
#             </td>
#             <td VALIGN=top><pre>2
# </pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>1234 1876 1568 1648 1934
# 21</pre>
#             </td>
#             <td VALIGN=top><pre>0
# </pre></td>
#         </tr>
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **В-02:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Условные конструкции. Цикл для перебора последовательностей. Работа со списками.*
#
# Митя хочет приобрести картины, однако у него есть купюры только номиналом 500 у.е.
#
# Напишите программу, которая поможет определить, какие картины он может купить без получения сдачи.
#
# **ФОРМАТ ВВОДА**
#
# На первой строке через запятую и пробел записываются данные о названии картины и о ее стоимости (вида <название картины> - <цена>).
# Гарантируется, что строка состоит из данных минимум об одной картине.
#
# **ФОРМАТ ВЫВОДА**
#
# Названия картин, которые Миша может купить, заплатив за нее и не получив сдачи.
# Названия должны быть выведены в алфавитном порядке на одной строке через запятую и пробел.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>Черный квадрат - 23000, Версаль - 14550, Осень - 12990, Ночь - 17000, Девятый вал - 25000</pre>
#             </td>
#             <td VALIGN=top><pre>Девятый вал, Ночь, Черный квадрат</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Осень - 12990, Мона Лиза - 23500</pre>
#             </td>
#             <td VALIGN=top><pre>Мона Лиза</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Версаль - 14550</pre>
#             </td>
#             <td VALIGN=top><pre>
# </pre></td>
#         </tr>
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **В-03:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Цикл для перебора последовательностей. Работа со списками. **Работа со словарями**. Сортировка.*
#
# Маша хочет подсчитать калорийность продуктов и определить самый низкокалорийный продукт.
#
# **ФОРМАТ ВВОДА**
#
# На первой строке через пробел вводятся названия продуктов.
# На второй строке вводятся соответствующая продуктам информация о количестве белков, жиров и углеводов в формате '<белки>-<жиры>-<углеводы>'.  Между собой информация разделена пробелами.
# Гарантируется, что названия продуктов не повторяются.
# Гарантируется, что строки состоят минимум из информации об одном продукте.
#
# **ФОРМАТ ВЫВОДА**
#
# Название самого низкокалорийного товара.
# Калорийность Маша определяет по следующей формуле: 0.4 x белки + 0.3 x жиры + 0.3 x углеводы.
# Гарантируется, что такой товар только один.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>банан мандарин кефир курочка
# 120-130-190 156-182-190 120-145-90 1390-129-1023</pre>
#             </td>
#             <td VALIGN=top><pre>кефир</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>молоко
# 120-120-120</pre>
#             </td>
#             <td VALIGN=top><pre>молоко</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>молоко творог яйцо клубника
# 130-120-110 160-170-189 153-891-291 170-180-190
# </pre>
#             </td>
#             <td VALIGN=top><pre>молоко</pre></td>
#         </tr>
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **С-01:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Цикл с условием. Работа со списками. Работа со словарями, вложенными структурами. Сортировка. Подсчет статистик (сумма, среднее, максимум, минимум).*
#
# Вы работаете аналитиком в торговой сети и изучаете суммарную прибыль по каждой из категории товаров. Найдите товар, приносящий максимальную суммарную прибыль.
#
# **ФОРМАТ ВВОДА**
#
# Записи о продаже товаров: название товара и, через запятую, полученная с этой продажи прибыль (целое число). Каждая запись вводится с новой строки. Название товара может содержать любые символы, кроме запятой.
# Один товар могут продавать любое количество раз, но в каждой строке указывается информация только про одну продажу.
# Когда записи заканчиваются, на отдельной строке вводится слово "END".
#
# **ФОРМАТ ВЫВОДА**
#
# Название товара, который принес наибольшую суммарную прибыль и, через пробел, сумма этой прибыли.
# Гарантируется, что такой товар только один.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>Шоколад,1000
# Мармеладки,600
# Шоколад,6000
# Киндер-сюрприз,1000
# Мармеладки,300
# END</pre>
#             </td>
#             <td VALIGN=top><pre>Шоколад 7000</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Шоколад,1000
# END</pre>
#             </td>
#             <td VALIGN=top><pre>Шоколад 1000</pre></td>
#         </tr>
#
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# ### Задания для самостоятельного решения:
#
# Поднимем немного настроение и самооценку и порешаем задания А-01 - А-04:
#
# **А-01:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Создание переменных. Вывод данных. Форматирование строк.*
#
# Реализуйте следующую программу:
#
# На первой строке вводится имя человека (строка).
# Затем вводится целое число — 1 или 0.
# Программа должна вывести фразу вида 'На праздник приглашена <ИМЯ>. Она будет одна? <True, если введено число 1; False иначе>'.
#
# *Важно! В коде обязательно нужно использовать f-строку!*
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>Лера
# 1</pre>
#             </td>
#             <td VALIGN=top><pre>На праздник приглашена Лера. Она будет одна? True</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Мария-Елизавета
# 0</pre>
#             </td>
#             <td VALIGN=top><pre>На праздник приглашена Мария-Елизавета. Она будет одна? False</pre></td>
#         </tr>
# <tr>
#             <td>
#                 <pre>Анастасия
# 1</pre>
#             </td>
#             <td VALIGN=top><pre>На праздник приглашена Анастасия. Она будет одна? True</pre></td>
#         </tr>
#
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **А-02:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Условные конструкции.*
#
# Реализуйте программу, которая проверяет, к какой платежной системе относится банковская карта.
#
# Дан список fd, где хранятся возможные комбинации первых двух цифр для карт платежной системы MasterCard.
# Вводится номер банковской карты, которую нужно проверить.
# Если количество цифр в номере карты равно 16 и первые две цифры совпадают с комбинацией из списка fd, то программа печатает строку "Это обычная карта MasterCard". Эта фраза сохранена для вас в переменной mastercard.
# Если количество цифр в номере карты равно 13 и первые две цифры совпадают с комбинацией из списка fd, то программа печатает строку "Это карта MasterCard с сокращенным номером". Эта фраза сохранена для вас в переменную mastercard_short.
# Во всех остальных случаях программа печатает "Это неизвестная карта". Эта фраза сохранена для вас в переменную noname.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>5275628475639104</pre>
#             </td>
#             <td VALIGN=top><pre>Это обычная карта MasterCard</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>5484769884726</pre>
#             </td>
#             <td VALIGN=top><pre>Это карта MasterCard с сокращенным номером</pre></td>
#         </tr>
# <tr>
#             <td>
#                 <pre>0</pre>
#             </td>
#             <td VALIGN=top><pre>Это неизвестная карта</pre></td>
#         </tr>
#
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **А-03:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Цикл с условием.*
#
# Реализуйте программу, сохраняющую в список товары, издержки на перевозку которых не превосходят 500 рублей.
#
# В цикле while считываются строки типа '<название товара>:<издержки на перевозку>' до тех пор, пока не введена строка 'END' .
# Для каждой вводимой строки сделайте проверку: если издержки (целое число) не более 500 — добавьте название товара в список.
# Гарантируется, что до строки 'END' будет введена как минимум одна строка.
# Напечатайте получившийся список. Строки в нем должны идти в том же порядке, что и при вводе.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>Шины:1200
# Iphone 13 Pro:500
# Замороженные котлеты:150
# Табуретки:340
# Одеяла:130
# END</pre>
#             </td>
#             <td VALIGN=top><pre>['Iphone 13 Pro', 'Замороженные котлеты', 'Табуретки', 'Одеяла']</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Одеяла:1130
# END</pre>
#             </td>
#             <td VALIGN=top><pre>[]</pre></td>
#         </tr>
#
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты

# %% [markdown]
# **А-04:**
#
# **ЧТО ПОВТОРЯЕМ:**
# *Цикл для перебора последовательностей. Методы строк и списков.*
#
# Реализуйте программу, которая фильтрует студентов на основании результатов сданных международных экзаменов по английскому языку.
#
# На первой строке через пробел вводятся фамилии студентов.
# На второй строке через пробел вводятся вещественные числа — набранные баллы за экзамены.
# Гарантируется, что будет введена информация минимум для одного студента.
# Программа выводит фамилии студентов, баллы которых не менее среднего арифметического всех баллов, каждую на новой строке.
#
# <table>
#     <thead>
#         <tr>
#             <th>Ввод</th>
#             <th>Вывод</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <pre>Иванова Петрова Питонова Семенова
# 5.6 4.5 6.7 3</pre>
#             </td>
#             <td VALIGN=top><pre>Иванова
# Питонова</pre></td>
#         </tr>
#
# <tr>
#             <td>
#                 <pre>Алексеева Орлова Александрова
# 1 1 1</pre>
#             </td>
#             <td VALIGN=top><pre>Алексеева
# Орлова
# Александрова</pre></td>
#         </tr>
#
# </table>

# %%
#напишите программу и протестируйте её в этой ячейке
#обязательно придумайте свои тесты
